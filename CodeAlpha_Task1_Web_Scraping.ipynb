# %% [markdown]
# <a href="https://colab.research.google.com/github/Anu-cse/CodeAlpha-Data-Analytics/blob/main/CodeAlpha_Task1_Web_Scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# CodeAlpha Data Analytics Internship
# Task 1: Web Scraping
# Project: Book Data Web Scraping Using Python and BeautifulSoup

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = "https://books.toscrape.com/"
response = requests.get(url)
print("Status Code:", response.status_code)
# Out:
# Status Code: 200

# %%
soup = BeautifulSoup(response.text, "html.parser")
books = soup.find_all("article", class_="product_pod")
print("Number of books found:", len(books))
# Out:
# Number of books found: 20

# %%
data = []
for book in books:
    title = book.h3.a["title"]
    price = book.find("p", class_="price_color").text
    rating = book.p["class"][1]
    availability = book.find(
        "p", class_="instock availability"
    ).text.strip()
    data.append({
        "Title":title,
        "Price":price,
        "Rating":rating,
        "Availability":availability
    })
print("Books scraped successfully:", len(data))
# Out:
# Books scraped successfully: 20

# %%
df = pd.DataFrame(data)
display(df)
# Out:
#                                                 Title    Price Rating  \
# 0                                A Light in the Attic  Â£51.77  Three
# 1                                  Tipping the Velvet  Â£53.74    One
# 2                                          Soumission  Â£50.10    One
# 3                                       Sharp Objects  Â£47.82   Four
# 4               Sapiens: A Brief History of Humankind  Â£54.23   Five
# 5                                     The Requiem Red  Â£22.65    One
# 6   The Dirty Little Secrets of Getting Your Dream...  Â£33.34   Four
# 7   The Coming Woman: A Novel Based on the Life of...  Â£17.93  Three
# 8   The Boys in the Boat: Nine Americans and Their...  Â£22.60   Four
# 9                                     The Black Maria  Â£52.15    One
# 10     Starving Hearts (Triangular Trade Trilogy, #1)  Â£13.99    Two
# 11                              Shakespeare's Sonnets  Â£20.66   Four
# ...

# %%
df["Price"] = df["Price"].str.replace("Â£", "£", regex=False)
display(df.head())
# Out:
#                                    Title   Price Rating Availability
# 0                   A Light in the Attic  £51.77  Three     In stock
# 1                     Tipping the Velvet  £53.74    One     In stock
# 2                             Soumission  £50.10    One     In stock
# 3                          Sharp Objects  £47.82   Four     In stock
# 4  Sapiens: A Brief History of Humankind  £54.23   Five     In stock

# %%
print("Dataset Shape:", df.shape)
print("\nColumn Names:")
print(df.columns.tolist())
print("\nFirst 5 Records:")
display(df.head())
# Out:
# Dataset Shape: (20, 4)
#
# Column Names:
# ['Title', 'Price', 'Rating', 'Availability']
#
# First 5 Records:
#                                    Title   Price Rating Availability
# 0                   A Light in the Attic  £51.77  Three     In stock
# 1                     Tipping the Velvet  £53.74    One     In stock
# 2                             Soumission  £50.10    One     In stock
# 3                          Sharp Objects  £47.82   Four     In stock
# 4  Sapiens: A Brief History of Humankind  £54.23   Five     In stock

# %%
print("Missing Values:")
print(df.isnull().sum())
# Out:
# Missing Values:
# Title           0
# Price           0
# Rating          0
# Availability    0
# dtype: int64

# %%
print("Data Types:")
print(df.dtypes)
# Out:
# Data Types:
# Title           object
# Price           object
# Rating          object
# Availability    object
# dtype: object

# %%
df.to_csv(
    "books_dataset.csv",
    index=False,
    encoding="utf-8-sig"
)
print("Dataset saved successfully!")
# Out:
# Dataset saved successfully!

# %%
print("Final Dataset")
print("=" * 50)
print("Total Records:", len(df))
print("Total Columns:", len(df.columns))
display(df)
# Out:
# Final Dataset
# ...
# Total Records: 20
# Total Columns: 4
#                                                 Title   Price Rating  \
# 0                                A Light in the Attic  £51.77  Three
# 1                                  Tipping the Velvet  £53.74    One
# 2                                          Soumission  £50.10    One
# 3                                       Sharp Objects  £47.82   Four
# 4               Sapiens: A Brief History of Humankind  £54.23   Five
# 5                                     The Requiem Red  £22.65    One
# 6   The Dirty Little Secrets of Getting Your Dream...  £33.34   Four
# 7   The Coming Woman: A Novel Based on the Life of...  £17.93  Three
# 8   The Boys in the Boat: Nine Americans and Their...  £22.60   Four
# 9                                     The Black Maria  £52.15    One
# 10     Starving Hearts (Triangular Trade Trilogy, #1)  £13.99    Two
# 11                              Shakespeare's Sonnets  £20.66   Four
# ...

# %% [markdown]
# ## Objective
#
# The objective of this project is to extract book information from a public website using Python and BeautifulSoup. The collected information is organized into a structured dataset containing book title, price, rating, and availability.

# %% [markdown]
# ## Tools and Libraries Used
#
# - Python
# - Requests
# - BeautifulSoup
# - Pandas
# - Google Colab

# %% [markdown]
# ## Methodology
#
# * Selected a publicly available website for web scraping.
# * Sent a request to the website using the Requests library.
# * Used BeautifulSoup to read and parse the HTML structure.
# * Identified the required book information from the webpage.
# * Extracted the title, price, rating, and availability of each book.
# * Stored the extracted information in a Pandas DataFrame.
# * Checked the dataset for missing values and data types.
# * Saved the final dataset as a CSV file.

# %% [markdown]
# ## Dataset Description
#
# The dataset contains information collected from the first page of the Books to Scrape website.
# The dataset includes the following columns:
# - Title – Name of the book
# - Price – Price of the book
# - Rating – Rating given to the book
# - Availability – Availability status of the book
#
# Total records collected: 20
# Total columns: 4

# %% [markdown]
# ## Result
#
# The web scraping process was successfully completed. A dataset containing 20 book records was extracted from the website and stored in a structured format.
#
# The final dataset was also saved as `books_dataset.csv`.

# %% [markdown]
# ## Conclusion
#
# This project demonstrates how Python and BeautifulSoup can be used to collect structured information from a public webpage. The extracted data was cleaned, checked, organized using Pandas, and saved as a CSV dataset for further analysis.
